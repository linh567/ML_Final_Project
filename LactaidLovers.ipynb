# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('fall-2025-ml-course-project\\cattle_data_train.csv',sep=',', skipinitialspace=True)
print(df.shape)

#mastitis is inflammation of breast tissue
#parity is the number of times a cow has given birth

#TODO
#combine vaccines together 
#drop date
#feed qunatity is in kg and lb (drop lbs)
#cthink about farm_ID 

feed = df.loc[1:10000,"Feed_Quantity_kg"]
milk_yield = df.loc[1:10000,"Milk_Yield_L"]
housing_score= df.loc[1:10000,"Housing_Score"]
df.plot.scatter(x='Feed_Quantity_kg', y='Milk_Yield_L')
plt.plot()
plt.title('feed quantity vs milk yield')
plt.scatter(feed, milk_yield)
plt.show()

plt.title('housing score vs milk yield')
plt.scatter(housing_score, milk_yield)
plt.show()


farms = df['Farm ID'].unique()
print(farms)
# plt.plot()
# plt.title('farm id and mean milk yield')
# plt.bar


# df.plot.scatter(x=df.loc[:,'housing '], y='charges')
# Out:
# (210000, 36)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Annie\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Farm ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 31
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("cattle_data_train.csv")

Compute correlations with Feed_Quantity_kg
correlations = (
    df.corr(numeric_only=True)["Feed_Quantity_kg"]
      .sort_values(ascending=False)
)

print(correlations)

corrs = (
    df.groupby(["Farm_ID"])[["Milk_Yield_L", "Feed_Quantity_kg"]]
    .corr()
    .iloc[0::2, 1]
)

farm_correlations = corrs.sort_values(ascending=False)
print(farm_correlations)
